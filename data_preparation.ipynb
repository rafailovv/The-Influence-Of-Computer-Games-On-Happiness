# %% [markdown]
# # Влияние компьютерных игр на счастье
# Данное исследование направлено на выявление зависимости (или отсутствия зависимости) компьютерных игр на счастье.
# Я собрал небольшую выборку (n=21) про помощи опроса для дальнейшего анализа.
# Данные о выборке находятся в файле data.csv.

# %% [markdown]
# ## Очистка и подготовка данных
# Прежде чем начать анализировать что-либо, наши данные нужно очистить и подговить.
# Сейчас мы займемся этим.

# %%
import pandas as pd


df = pd.read_csv("data.csv")
df.head(5)
# Out:
#            ID  Сколько Вам лет? Укажите Ваш пол?  \
# 0  1855465575                19          Мужчина
# 1  1856114803                20          Мужчина
# 2  1856117571                19          Мужчина
# 3  1856208774                20          Мужчина
# 4  1856316803                20          Мужчина
#
#    Сколько часов в сутки Вы тратите на компьютерные игры?  \
# 0                                                  3
# 1                                                  4
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    Сколько дней в неделю Вы играете в компьютерные игры?  \
# 0                                                  1
# 1                                                  6
# 2                                                  1
# 3                                                  2
# 4                                                  0
#
#   Какой тип игр Вы предпочитаете?  \
# 0                       Одиночные
# 1                     Мультиплеер
# 2                     Мультиплеер
# 3                     Мультиплеер
# 4                       Одиночные
#
#   Как часто Вы играете в игры с вашими друзьями?  \
# 0                          Чаще играю с друзьями
# 1                        Играю только с друзьями
# 2                          Чаще играю с друзьями
# 3                        Играю только с друзьями
# 4                            Не играю с друзьями
#
#   Компьютерные игры играют значительную роль в Вашей жизни?  \
# 0                                                 Да
# 1                                                 Да
# 2                                                 Да
# 3                                                 Да
# 4                                                Нет
#
#   Вы зависимы от компьютерных игр? Назовите Ваш любимый игровой жанр?  \
# 0                              Нет                        Приключения
# 1                               Да                               Экшн
# 2                              Нет                               Экшн
# 3                              Нет                       Ролевые игры
# 4                              Нет                        Приключения
#
#   Назовите Вашу любимую игру?  Насколько Вы счастливы? / Общее счастье  \
# 0              The Last Of Us                                        7
# 1                    Deadlock                                        7
# 2                    valorant                                        7
# 3                       тупик                                        7
# 4               The Witcher 3                                        8
#
#    Насколько Вы счастливы? / Личная жизнь  \
# 0                                       3
# 1                                       7
# 2                                       4
# 3                                      10
# 4                                       9
#
#    Насколько Вы счастливы? / Работа/Учеба  \
# 0                                       8
# 1                                       4
# 2                                       7
# 3                                       3
# 4                                       7
#
#    Как часто Вы испытываете следующие чувства? / Радость  \
# 0                                                  4
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    Как часто Вы испытываете следующие чувства? / Стресс
# 0                                                  2
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  1

# %% [markdown]
# Как можно заметить, названия колонок на русском языке. Поменяем это

# %%
df = df.rename(columns={
    "ID": "id",
    "Сколько Вам лет?": "age",
    "Укажите Ваш пол?": "gender",
    "Сколько часов в сутки Вы тратите на компьютерные игры?": "game_hours_per_day",
    "Сколько дней в неделю Вы играете в компьютерные игры?": "game_days_per_week",
    "Какой тип игр Вы предпочитаете?": "game_type",
    "Как часто Вы играете в игры с вашими друзьями?": "game_friends_activity",
    "Компьютерные игры играют значительную роль в Вашей жизни?": "game_importance",
    "Вы зависимы от компьютерных игр?": "game_addiction",
    "Назовите Ваш любимый игровой жанр?": "game_genre",
    "Назовите Вашу любимую игру?": "game_favorite",
    "Насколько Вы счастливы? / Общее счастье": "happiness_general",
    "Насколько Вы счастливы? / Личная жизнь": "happiness_personal",
    "Насколько Вы счастливы? / Работа/Учеба": "happiness_work",
    "Как часто Вы испытываете следующие чувства? / Радость": "happiness_joy",
    "Как часто Вы испытываете следующие чувства? / Стресс": "happiness_stress"})

df.columns
# Out:
# Index(['id', 'age', 'gender', 'game_hours_per_day', 'game_days_per_week',
#        'game_type', 'game_friends_activity', 'game_importance',
#        'game_addiction', 'game_genre', 'game_favorite', 'happiness_general',
#        'happiness_personal', 'happiness_work', 'happiness_joy',
#        'happiness_stress'],
#       dtype='object')

# %% [markdown]
# Теперь поменяем местами некоторые столбцы для удобства

# %%
genre = df.game_genre
df = df.drop("game_genre", axis=1)
df.insert(6, "game_genre", genre)
df.head(5)
# Out:
#            id  age   gender  game_hours_per_day  game_days_per_week  \
# 0  1855465575   19  Мужчина                   3                   1
# 1  1856114803   20  Мужчина                   4                   6
# 2  1856117571   19  Мужчина                   0                   1
# 3  1856208774   20  Мужчина                   1                   2
# 4  1856316803   20  Мужчина                   0                   0
#
#      game_type    game_genre    game_friends_activity game_importance  \
# 0    Одиночные   Приключения    Чаще играю с друзьями              Да
# 1  Мультиплеер          Экшн  Играю только с друзьями              Да
# 2  Мультиплеер          Экшн    Чаще играю с друзьями              Да
# 3  Мультиплеер  Ролевые игры  Играю только с друзьями              Да
# 4    Одиночные   Приключения      Не играю с друзьями             Нет
#
#   game_addiction   game_favorite  happiness_general  happiness_personal  \
# 0            Нет  The Last Of Us                  7                   3
# 1             Да        Deadlock                  7                   7
# 2            Нет        valorant                  7                   4
# 3            Нет           тупик                  7                  10
# 4            Нет   The Witcher 3                  8                   9
#
#    happiness_work  happiness_joy  happiness_stress
# 0               8              4                 2
# 1               4              5                 3
# 2               7              4                 3
# 3               3              4                 2
# 4               7              4                 1

# %% [markdown]
# Теперь пройдемся по столбцам и проверим, все ли значения в корректном формате

# %%
df.dtypes
# Out:
# id                        int64
# age                       int64
# gender                   object
# game_hours_per_day        int64
# game_days_per_week        int64
# game_type                object
# game_genre               object
# game_friends_activity    object
# game_importance          object
# game_addiction           object
# game_favorite            object
# happiness_general         int64
# happiness_personal        int64
# happiness_work            int64
# happiness_joy             int64
# happiness_stress          int64
# dtype: object

# %%
df.age.value_counts()
# Out:
# age
# 20    10
# 19     5
# 21     5
# 1      1
# Name: count, dtype: int64

# %%
df[df.age == 1].index
df.loc[15, "age"] = df[df.age != 1].age.mean()
df.age.value_counts()
# Out:
# age
# 20    11
# 19     5
# 21     5
# Name: count, dtype: int64

# %%
df.gender = df.gender.map({"Мужчина": "M", "Женщина": "F"}, na_action='ignore')
df.gender.value_counts()
# Out:
# gender
# M    17
# F     4
# Name: count, dtype: int64

# %%
df.game_type = df.game_type.map({"Одиночные": "Single", "Мультиплеер": "Multiplayer"})
df.game_type.value_counts()
# Out:
# game_type
# Multiplayer    13
# Single          8
# Name: count, dtype: int64

# %%
df.game_genre.value_counts()
# Out:
# game_genre
# Приключения     5
# MOBA            5
# Стратегии       5
# Экшн            4
# Ролевые игры    1
# Головоломки     1
# Name: count, dtype: int64

# %%
df.game_genre = df.game_genre.map({
    "Приключения": "Adventure",
    "MOBA": "MOBA",
    "Стратегии": "Strategy",
    "Экшн": "Action",
    "Ролевые игры": "Role-Play",
    "Головоломки": "Puzzles"})
df.game_genre.value_counts()
# Out:
# game_genre
# Adventure    5
# MOBA         5
# Strategy     5
# Action       4
# Role-Play    1
# Puzzles      1
# Name: count, dtype: int64

# %%
df.game_importance = df.game_importance.map({"Да": "Y", "Нет": "N"})
df.game_addiction = df.game_addiction.map({"Да": "Y", "Нет": "N"})
df.head(5)
# Out:
#            id  age gender  game_hours_per_day  game_days_per_week  \
# 0  1855465575   19      M                   3                   1
# 1  1856114803   20      M                   4                   6
# 2  1856117571   19      M                   0                   1
# 3  1856208774   20      M                   1                   2
# 4  1856316803   20      M                   0                   0
#
#      game_type game_genre    game_friends_activity game_importance  \
# 0       Single  Adventure    Чаще играю с друзьями               Y
# 1  Multiplayer     Action  Играю только с друзьями               Y
# 2  Multiplayer     Action    Чаще играю с друзьями               Y
# 3  Multiplayer  Role-Play  Играю только с друзьями               Y
# 4       Single  Adventure      Не играю с друзьями               N
#
#   game_addiction   game_favorite  happiness_general  happiness_personal  \
# 0              N  The Last Of Us                  7                   3
# 1              Y        Deadlock                  7                   7
# 2              N        valorant                  7                   4
# 3              N           тупик                  7                  10
# 4              N   The Witcher 3                  8                   9
#
#    happiness_work  happiness_joy  happiness_stress
# 0               8              4                 2
# 1               4              5                 3
# 2               7              4                 3
# 3               3              4                 2
# 4               7              4                 1

# %% [markdown]
# Для колонки $game\_friends\_activity$ введем следующие обозначения:
# Не играю с друзьями - 0
# Чаще играю один	- 1
# Играю с друзьями и наедине поровну - 2
# Чаще играю с друзьями - 3
# Играю только с друзьями - 4

# %%
df.game_friends_activity = df.game_friends_activity.map({
    "Не играю с друзьями": "0",
    "Чаще играю один": "1",
    "Играю с друзьями и наедине поровну": "2",
    "Чаще играю с друзьями": "3",
    "Играю только с друзьями": "4"})
df.game_friends_activity = df.game_friends_activity.astype("int64")
df
# Out:
#             id  age gender  game_hours_per_day  game_days_per_week  \
# 0   1855465575   19      M                   3                   1
# 1   1856114803   20      M                   4                   6
# 2   1856117571   19      M                   0                   1
# 3   1856208774   20      M                   1                   2
# 4   1856316803   20      M                   0                   0
# 5   1856323161   19      M                   3                   7
# 6   1856334638   20      M                   3                   4
# 7   1856325289   21      F                   5                   7
# 8   1856329943   19      M                   3                   4
# 9   1856330630   19      M                   2                   7
# 10  1856331876   20      M                   3                   3
# 11  1856338180   20      M                   3                   6
# 12  1856341158   20      M                   1                   1
# 13  1856342228   21      M                  12                   7
# 14  1856343554   21      F                   2                   4
# 15  1856343886   20      F                  24                   7
# 16  1856346441   20      M                   5                   4
# 17  1856484736   21      M                   6                   7
# 18  1856772760   21      M                   7                   7
# 19  1856907712   20      F                   4                   6
# 20  1857034677   20      M                   8                   6
#
#       game_type game_genre  game_friends_activity game_importance  \
# 0        Single  Adventure                      3               Y
# 1   Multiplayer     Action                      4               Y
# 2   Multiplayer     Action                      3               Y
# 3   Multiplayer  Role-Play                      4               Y
# 4        Single  Adventure                      0               N
# 5   Multiplayer       MOBA                      2               N
# 6   Multiplayer     Action                      3               Y
# 7        Single  Adventure                      1               Y
# 8   Multiplayer       MOBA                      4               Y
# 9        Single  Adventure                      1               Y
# 10  Multiplayer     Action                      2               Y
# 11       Single   Strategy                      3               Y
# 12       Single   Strategy                      1               N
# 13  Multiplayer       MOBA                      3               Y
# 14       Single  Adventure                      1               Y
# 15       Single    Puzzles                      4               N
# 16  Multiplayer       MOBA                      3               Y
# 17  Multiplayer       MOBA                      2               Y
# 18  Multiplayer   Strategy                      2               Y
# 19  Multiplayer   Strategy                      2               Y
# 20  Multiplayer   Strategy                      1               Y
#
#    game_addiction      game_favorite  happiness_general  happiness_personal  \
# 0               N     The Last Of Us                  7                   3
# 1               Y           Deadlock                  7                   7
# 2               N           valorant                  7                   4
# 3               N              тупик                  7                  10
# 4               N      The Witcher 3                  8                   9
# 5               N   SMITE, Minectaft                  7                  10
# 6               Y                 CS                  7                   2
# 7               Y    Stardew valley                  10                   7
# 8               Y             Dora 2                  6                   6
# 9               N     Genshin Impact                  8                   9
# 10              N            Enderal                  8                   1
# 11              Y             gta 4                   6                   2
# 12              N       Pathalogic 2                  5                   8
# 13              Y             DOTA 2                 10                   2
# 14              Y          Ведьмак 3                  8                   9
# 15              N            Пасьянс                 10                   1
# 16              Y        Prototype 2                  8                   9
# 17              Y             Dota 2                  8                   3
# 18              Y  World of warcraft                  7                   6
# 19              N           Diablo 2                 10                   5
# 20              Y             Дота 2                  5                   1
#
#     happiness_work  happiness_joy  happiness_stress
# 0                8              4                 2
# 1                4              5                 3
# 2                7              4                 3
# 3                3              4                 2
# 4                7              4                 1
# 5                8              5                 5
# 6                5              4                 1
# 7               10              5                 3
# 8                6              3                 3
# 9                8              3                 3
# 10               6              5                 4
# 11               4              4                 1
# 12               7              3                 5
# 13               6              5                 1
# 14               4              3                 4
# 15               1              1                 1
# 16               7              4                 4
# 17               5              5                 1
# 18               6              4                 3
# 19               8              4                 2
# 20               1              3                 5

# %% [markdown]
# Столбец $game\_favorite$ придется править вручную из-за частых ошибок ввода.

# %%
df.game_favorite = df.game_favorite.apply(str.title)
df.loc[:, ["id", "game_favorite"]]
# Out:
#             id      game_favorite
# 0   1855465575     The Last Of Us
# 1   1856114803           Deadlock
# 2   1856117571           Valorant
# 3   1856208774              Тупик
# 4   1856316803      The Witcher 3
# 5   1856323161   Smite, Minectaft
# 6   1856334638                 Cs
# 7   1856325289    Stardew Valley
# 8   1856329943             Dora 2
# 9   1856330630     Genshin Impact
# 10  1856331876            Enderal
# 11  1856338180             Gta 4
# 12  1856341158       Pathalogic 2
# 13  1856342228             Dota 2
# 14  1856343554          Ведьмак 3
# 15  1856343886            Пасьянс
# 16  1856346441        Prototype 2
# 17  1856484736             Dota 2
# 18  1856772760  World Of Warcraft
# 19  1856907712           Diablo 2
# 20  1857034677             Дота 2

# %%
df.loc[5, "game_favorite"] = "Minecraft"
df.loc[6, "game_favorite"] = "Counter Strike 2"
df.loc[8, "game_favorite"] = "Dota 2"
df.loc[11, "game_favorite"] = "GTA 4"
df.loc[14, "game_favorite"] = "The Witcher 3"
df.loc[15, "game_favorite"] = "Solitaire"
df.loc[20, "game_favorite"] = "Dota 2"
df.loc[3, "game_favorite"] = df.game_favorite.mode().values[0]

df.game_favorite.value_counts()
# Out:
# game_favorite
# Dota 2               5
# The Witcher 3        2
# The Last Of Us       1
# Deadlock             1
# Valorant             1
# Minecraft            1
# Counter Strike 2     1
# Stardew Valley       1
# Genshin Impact       1
# Enderal              1
# GTA 4                1
# Pathalogic 2         1
# Solitaire            1
# Prototype 2          1
# World Of Warcraft    1
# Diablo 2             1
# Name: count, dtype: int64

# %% [markdown]
# Теперь, когда все наши данные в порядке, мы можем сохранить файл и приступить к анализу

# %%
df.to_csv("data_prepared.csv", index=False)
